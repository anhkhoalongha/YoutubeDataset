# %% [markdown]
# ## Đọc bộ dữ liệu mẫu

# %%
import pandas as pd

# %%
data = pd.read_excel("/content/drive/MyDrive/DoAnTienXuLiDuLieu/Dataset/merged_data.xlsx")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data.columns
# Out:
# Index(['channelId', 'videoId', 'title', 'Description', 'ChannelViewCount',
#        'subscriberCount', 'viewCount', 'likeCount', 'Duration'],
#       dtype='object')

# %%
data['ChannelViewCount'] = pd.to_numeric(data['ChannelViewCount'], downcast='integer')
data['subscriberCount'] = pd.to_numeric(data['subscriberCount'], downcast='integer')
data['viewCount'] = pd.to_numeric(data['viewCount'], downcast='integer')
data['likeCount'] = pd.to_numeric(data['likeCount'], downcast='integer')

# %% [markdown]
# ## Phân tích dữ liệu

# %% [markdown]
# ### Chọn ra top 10 video có lượt view cao nhất

# %%
data.sort_values('viewCount',ascending = False).head(10)
# Out:
#                      channelId      videoId  \
# 4151  UCdb3QmyzSVTrjqLwUzkiZ7g  9RZtPJIH-Vs
# 1144  UCbm1H5lQ7TLMNwwJALinjww  nz798qDoTvQ
# 5301  UClK8w-hLJlhR6fL5_xQg_VA  SFBIQdGLvmE
# 4556  UClK8w-hLJlhR6fL5_xQg_VA  ZsXZbC3CCzU
# 9765  UC4Jw36rrtdMdW99PeCtNwxA  pr99IU6tv2k
# 3025  UCbIZSalhHyz3RNWj2wowzdQ  mZE0IxQhW5o
# 2018  UCSgRTrXXnt7j-Zc8ka_TeiA  Tiiops6zHtU
# 6737  UCHu12Ozb1VdI_vyOurlSzCg  fZzSkz5SAbE
# 3517  UCjzHeG1KWoonmf9d5KBvSiw  -_cmaJGR_I4
# 1027  UCdNKGYGIdNFByq9ayw_Syjg  08fp9nDDGaQ
#
#                                                   title  \
# 4151        Thương Lắm Thầy Cô Ơi! - Bé Phan Hiếu Kiên
# 1144  Một Con Vịt - Nhạc Thiếu Nhi - hoạt hình một c...
# 5301  Loạt trò chơi ngoài trời Nastya Katya và Max d...
# 4556  Loạt trò chơi ngoài trời Nastya Katya và Max d...
# 9765   Đại Ca Lớp 12A ( Túy Âm + Save Me Parody ) - LEG
# 3025       [Nhạc chế] - SỨC MẠNH CỦA SAO ĐỎ | Hậu Hoàng
# 2018  Ba Thương con - Bống Bống bang bang - Cái bống...
# ...

# %% [markdown]
# 5/10 video có lượt xem cao nhất thuộc về danh mục âm nhạc, trong đó có 4 video là nhạc thiếu nhi.

# %% [markdown]
# ### Chọn ra các kênh có lượt theo dõi cao nhất

# %%
channels = data[["channelId","subscriberCount"]].drop_duplicates(subset="channelId").sort_values('subscriberCount',ascending = False).head(15)

# %%
channels
# Out:
#                      channelId  subscriberCount
# 9311  UCOmHUn--16B90oW2L6FRR3A       74600000.0
# 1590  UCu59yAFE8fM0sVNTipR4edw       34000000.0
# 880   UCcOMTVILq-yIqtFmOqt-QOg       24100000.0
# 7028  UCfLuT3JwLx8rvHjHfTymekw       16200000.0
# 174   UC5ezaYrzZpyItPSRG27MLpg       14800000.0
# 1346  UCqmld-BIYME2i_ooRTo1EOg       14400000.0
# 551   UClK8w-hLJlhR6fL5_xQg_VA       13800000.0
# 2923  UC34xi8JB1AKSotPUKHywbaA       13600000.0
# 1560  UC0jDoh3tVXCaqJ6oTve8ebA       13300000.0
# 1504  UCqYw-CTd1dU2yGI71sEyqNw       11700000.0
# 238   UC6eq3sR4CtbvGdmInchzWUA       10700000.0
# 3572  UCd0neB_LB1xpwIYDetX2qTg       10400000.0
# 6004  UCiZJtnTQunvoY0xgv-Ce_rg       10200000.0
# 5074  UCkna2OcuN1E6u5I8GVtdkOw        9840000.0
# 2477  UCjzHeG1KWoonmf9d5KBvSiw        9520000.0

# %%
pip install python-youtube
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 42 kB 580 kB/s
# ...
#      |████████████████████████████████| 62 kB 1.4 MB/s
# ...
#      |████████████████████████████████| 41 kB 627 kB/s
# ...
#      |████████████████████████████████| 47 kB 5.0 MB/s
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests~=2.23.0, but you have requests 2.28.0 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# ...

# %%
import pandas as pd
from pyyoutube import Api

key = "AIzaSyDcD3M2T6tCy1u61OGjeAacUceW3orOGMY"
listid = channels.channelId
api = Api(api_key=key)
for id in listid:
  print(api.get_channel_info(channel_id=id).items[0].to_dict()['brandingSettings']['channel']['title'])
# Out:
# BLACKPINK
# Masha and The Bear
# Vlad và Nikita
# Triggered Insaan
# POPS Kids
# Mobile Legends: Bang Bang Official
# Like Nastya VNM
# MNCTV OFFICIAL
# FAPTV
# GMA News
# Kênh Thiếu Nhi - BHMEDIA
# Cris Devil Gamer
# NTN
# Vie Channel - HTV2
# Soothing Relaxation

# %% [markdown]
# Trong các kênh có lượt theo dõi nhiều nhất, 5/15 là các kênh có nội dung hướng đến đối tượng là trẻ em (Masha and The Bear, Vlad và Nikita, POPS Kids, Like Nastya VNM, Kênh Thiếu Nhi - BHMEDIA). Qua 2 phân tích trên, ta có thể thấy các kênh hướng đến đối tượng người xem là trẻ em sẽ thu hút được nhiều lượt xem và lượt theo dõi nhất trong số các danh mục.

# %% [markdown]
# ### Tìm top 15 kênh có lượt xem nhiều nhất

# %%
channelsView = data[["channelId","ChannelViewCount"]].drop_duplicates(subset="channelId").sort_values('ChannelViewCount',ascending = False).head(15)
channelsView
# Out:
#                      channelId  ChannelViewCount
# 9311  UCOmHUn--16B90oW2L6FRR3A       23963460279
# 1590  UCu59yAFE8fM0sVNTipR4edw       18567651540
# 880   UCcOMTVILq-yIqtFmOqt-QOg       15385752973
# 1504  UCqYw-CTd1dU2yGI71sEyqNw       10060381857
# 238   UC6eq3sR4CtbvGdmInchzWUA        9672016322
# 174   UC5ezaYrzZpyItPSRG27MLpg        8337865886
# 30    UCUgXK2UjZ8G_EM438aYkGrw        7644845886
# 551   UClK8w-hLJlhR6fL5_xQg_VA        7496660483
# 2923  UC34xi8JB1AKSotPUKHywbaA        7303941002
# 185   UCA7QBnEDwHAEFTQpaNDT5Iw        6966743551
# 32    UCKl0tA90oEArasOGzp8I41g        6625119615
# 856   UCSJsjCiTl2lourZXnigVCoA        5267903910
# 488   UCtr3boXbtzcDAzY9b6M25NA        5008028684
# 181   UC7nMrW3baKp0dA5Tz9ulVYQ        4970492393
# 5026  UCXF15hEQI7y1hpoZK4cZDEQ        4957519650

# %%
listid = channelsView.channelId
api = Api(api_key=key)
for id in listid:
  print(api.get_channel_info(channel_id=id).items[0].to_dict()['brandingSettings']['channel']['title'])
# Out:
# BLACKPINK
# Masha and The Bear
# Vlad và Nikita
# GMA News
# Kênh Thiếu Nhi - BHMEDIA
# POPS Kids
# POPS MUSIC
# Like Nastya VNM
# MNCTV OFFICIAL
# BabyBus - Nhạc thiếu nhi
# Tony TV
# Thơ Nguyễn
# SlenderMan™
# Thuy Nga
# KN Channel

# %% [markdown]
# So với top 15 kênh có lượt theo dõi nhiều nhất, danh sách này tuy có sự thay đổi ở top dưới, nhưng vẫn là các kênh hướng đến đối tượng là trẻ em. Qua đó ta có thể thấy, các nội dung hướng đến đối tượng trẻ em có một vị thế không hề nhỏ.
#
# > Indented block

# %% [markdown]
# Phân phối tần số lượng lượt xem

# %%
import seaborn as sns

# %%
view_count= data['viewCount']

# %%
data_plot = sns.load_dataset(view_count)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-dff1f3a5306c> in <module>()
# ----> 1 data_plot = sns.load_dataset(view_count)
#
# /usr/local/lib/python3.7/dist-packages/seaborn/utils.py in load_dataset(name, cache, data_home, **kws)
#     592         cache_path = os.path.join(get_data_home(data_home), os.path.basename(url))
#     593         if not os.path.exists(cache_path):
# --> 594             if name not in get_dataset_names():
#     595                 raise ValueError(f"'{name}' is not one of the example datasets.")
#     596             urlretrieve(url, cache_path)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in __nonzero__(self)
#    1536     def __nonzero__(self):
#    1537         raise ValueError(
# -> 1538             f"The truth value of a {type(self).__name__} is ambiguous. "
# ...
